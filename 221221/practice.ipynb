# %%
import bollinger as bol
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../csv/BND.csv', index_col='Date')

# %%
df = bol.Bollinger(df, 'Adj Close', '2010-01-01')

# %%
df.testing()
# Out:
# c:\Users\seopa\OneDrive\Documents\6기\221221\bollinger\__init__.py:10: FutureWarning: In a future version of pandas all arguments of DataFrame.any and Series.any will be keyword-only.
#   self.df = self.df[~self.df.isin([np.nan, np.inf, -np.inf]).any(1)]
# 누적수익률: 1.0794
#             Adj Close     center         ub         lb trade  return   acc_rtn
# Date
# 2010-01-04  60.611969  60.826958  61.336124  60.317793           1.0  1.000000
# 2010-01-05  60.789135  60.819153  61.325461  60.312844           1.0  1.000000
# 2010-01-06  60.766037  60.802128  61.290324  60.313932           1.0  1.000000
# 2010-01-07  60.719822  60.777802  61.228214  60.327389           1.0  1.000000
# 2010-01-08  60.781410  60.759625  61.175685  60.343565           1.0  1.000000
# ...               ...        ...        ...        ...   ...     ...       ...
# 2019-06-18  82.397118  81.737070  82.743959  80.730181           1.0  1.079378
# 2019-06-19  82.676468  81.836350  82.799510  80.873191           1.0  1.079378
# 2019-06-20  82.806168  81.934650  82.870640  80.998661           1.0  1.079378
# 2019-06-21  82.576698  82.007045  82.903749  81.110341           1.0  1.079378
# 2019-06-24  82.726349  82.086923  82.937662  81.236184           1.0  1.079378
#
# [2384 rows x 7 columns]
